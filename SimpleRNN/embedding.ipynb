# %%
from tensorflow.keras.preprocessing.text  import one_hot

# %%
## sentances
sent=[
'the glass of milk',
'the glass of juice',
'I am a good boy',
'I am a good developer',
'understand the meaning of words',
'your videos are good'
]

# %%
## Define the vocabulary size
voc_size=10000

# %%
### One Hot Representation
one_hot_repr=[one_hot(words,voc_size) for words in sent]
one_hot_repr
# Out:
# [[3547, 1904, 1027, 9550],
#  [3547, 1904, 1027, 4771],
#  [9815, 539, 4535, 1202, 5615],
#  [9815, 539, 4535, 1202, 5156],
#  [1262, 3547, 5045, 1027, 6006],
#  [9927, 6005, 4930, 1202]]

# %%
## word embedding Representation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential
import numpy as np

# %%
sent_length=8
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 3547 1904 1027 9550]
#  [   0    0    0    0 3547 1904 1027 4771]
#  [   0    0    0 9815  539 4535 1202 5615]
#  [   0    0    0 9815  539 4535 1202 5156]
#  [   0    0    0 1262 3547 5045 1027 6006]
#  [   0    0    0    0 9927 6005 4930 1202]]

# %%
dim=10

# %%
## feature representation

model= Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# c:\Users\viv96\anaconda3\envs\venv\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# array([[[-0.02330211,  0.01627814, -0.04349464,  0.02309198,
#          -0.0032322 ,  0.01108183, -0.04514333, -0.00697652,
#          -0.00330598, -0.02367705],
#         [-0.02330211,  0.01627814, -0.04349464,  0.02309198,
#          -0.0032322 ,  0.01108183, -0.04514333, -0.00697652,
#          -0.00330598, -0.02367705],
#         [-0.02330211,  0.01627814, -0.04349464,  0.02309198,
#          -0.0032322 ,  0.01108183, -0.04514333, -0.00697652,
#          -0.00330598, -0.02367705],
#         [-0.02330211,  0.01627814, -0.04349464,  0.02309198,
#          -0.0032322 ,  0.01108183, -0.04514333, -0.00697652,
#          -0.00330598, -0.02367705],
#         [ 0.02160083,  0.02624402,  0.0375005 , -0.04109714,
#          -0.01176697, -0.02468352, -0.01452371,  0.00252197,
#          -0.02251412,  0.04260239],
#         [-0.04103637, -0.03638768,  0.00302026, -0.04552444,
#           0.01547173, -0.01538966, -0.00760535, -0.00087966,
#          -0.03987145, -0.03970847],
#         [ 0.04432554, -0.02949274,  0.00618243,  0.02000041,
#          -0.0274101 ,  0.00867223,  0.00422277, -0.01694552,
#          -0.03290661,  0.02646024],
#         [ 0.03764528, -0.02844671, -0.01868043,  0.00586253,
#          -0.02698125, -0.01830665,  0.04927624,  0.03458515,
#           0.03521678,  0.03454145]],
#
#        [[-0.02330211,  0.01627814, -0.04349464,  0.02309198,
#          -0.0032322 ,  0.01108183, -0.04514333, -0.00697652,
#          -0.00330598, -0.02367705],
#         [-0.02330211,  0.01627814, -0.04349464,  0.02309198,
#          -0.0032322 ,  0.01108183, -0.04514333, -0.00697652,
#          -0.00330598, -0.02367705],
#         [-0.02330211,  0.01627814, -0.04349464,  0.02309198,
#          -0.0032322 ,  0.01108183, -0.04514333, -0.00697652,
#          -0.00330598, -0.02367705],
#         [-0.02330211,  0.01627814, -0.04349464,  0.02309198,
#          -0.0032322 ,  0.01108183, -0.04514333, -0.00697652,
#          -0.00330598, -0.02367705],
#         [ 0.02160083,  0.02624402,  0.0375005 , -0.04109714,
#          -0.01176697, -0.02468352, -0.01452371,  0.00252197,
#          -0.02251412,  0.04260239],
#         [-0.04103637, -0.03638768,  0.00302026, -0.04552444,
#           0.01547173, -0.01538966, -0.00760535, -0.00087966,
#          -0.03987145, -0.03970847],
#         [ 0.04432554, -0.02949274,  0.00618243,  0.02000041,
#          -0.0274101 ,  0.00867223,  0.00422277, -0.01694552,
#          -0.03290661,  0.02646024],
#         [-0.00953829,  0.02068797,  0.01177833,  0.01484537,
#          -0.02160834, -0.04199362,  0.02882589, -0.03233746,
#          -0.02316247, -0.0318886 ]],
#
#        [[-0.02330211,  0.01627814, -0.04349464,  0.02309198,
#          -0.0032322 ,  0.01108183, -0.04514333, -0.00697652,
#          -0.00330598, -0.02367705],
#         [-0.02330211,  0.01627814, -0.04349464,  0.02309198,
#          -0.0032322 ,  0.01108183, -0.04514333, -0.00697652,
#          -0.00330598, -0.02367705],
#         [-0.02330211,  0.01627814, -0.04349464,  0.02309198,
#          -0.0032322 ,  0.01108183, -0.04514333, -0.00697652,
#          -0.00330598, -0.02367705],
#         [ 0.01822865, -0.00669253,  0.03243135,  0.01095785,
#           0.01354065,  0.03076063, -0.00194311,  0.00055168,
#          -0.02027289, -0.03089696],
#         [-0.04749478,  0.03135213,  0.0180291 , -0.00787222,
#          -0.04772366,  0.01991266, -0.00972386,  0.00192457,
#           0.04907021, -0.00873113],
#         [-0.02932422, -0.04465349,  0.04372838,  0.01361228,
#           0.02457588,  0.04527292, -0.0477729 ,  0.00480306,
#          -0.0452824 , -0.02070724],
#         [-0.04801533,  0.01840714,  0.04043165, -0.03367736,
#          -0.04605852, -0.04235249, -0.04783267,  0.03856683,
#          -0.02810522,  0.03464666],
#         [-0.04461559,  0.00719211, -0.00809775,  0.03348852,
#           0.04723344, -0.02168986, -0.00094444, -0.01433358,
#           0.01805611, -0.00761528]],
#
#        [[-0.02330211,  0.01627814, -0.04349464,  0.02309198,
#          -0.0032322 ,  0.01108183, -0.04514333, -0.00697652,
#          -0.00330598, -0.02367705],
#         [-0.02330211,  0.01627814, -0.04349464,  0.02309198,
#          -0.0032322 ,  0.01108183, -0.04514333, -0.00697652,
#          -0.00330598, -0.02367705],
#         [-0.02330211,  0.01627814, -0.04349464,  0.02309198,
#          -0.0032322 ,  0.01108183, -0.04514333, -0.00697652,
#          -0.00330598, -0.02367705],
#         [ 0.01822865, -0.00669253,  0.03243135,  0.01095785,
#           0.01354065,  0.03076063, -0.00194311,  0.00055168,
#          -0.02027289, -0.03089696],
#         [-0.04749478,  0.03135213,  0.0180291 , -0.00787222,
#          -0.04772366,  0.01991266, -0.00972386,  0.00192457,
#           0.04907021, -0.00873113],
#         [-0.02932422, -0.04465349,  0.04372838,  0.01361228,
#           0.02457588,  0.04527292, -0.0477729 ,  0.00480306,
#          -0.0452824 , -0.02070724],
#         [-0.04801533,  0.01840714,  0.04043165, -0.03367736,
#          -0.04605852, -0.04235249, -0.04783267,  0.03856683,
#          -0.02810522,  0.03464666],
#         [ 0.03118794, -0.00820692, -0.01310464,  0.01194913,
#          -0.01227214,  0.03626997, -0.0049515 ,  0.04214687,
#           0.00974001,  0.0196672 ]],
#
#        [[-0.02330211,  0.01627814, -0.04349464,  0.02309198,
#          -0.0032322 ,  0.01108183, -0.04514333, -0.00697652,
#          -0.00330598, -0.02367705],
#         [-0.02330211,  0.01627814, -0.04349464,  0.02309198,
#          -0.0032322 ,  0.01108183, -0.04514333, -0.00697652,
#          -0.00330598, -0.02367705],
#         [-0.02330211,  0.01627814, -0.04349464,  0.02309198,
#          -0.0032322 ,  0.01108183, -0.04514333, -0.00697652,
#          -0.00330598, -0.02367705],
#         [-0.0399044 ,  0.04154155, -0.04848098, -0.03208226,
#           0.02047164, -0.04731064,  0.0139483 ,  0.03990598,
#          -0.04965978,  0.00297616],
#         [ 0.02160083,  0.02624402,  0.0375005 , -0.04109714,
#          -0.01176697, -0.02468352, -0.01452371,  0.00252197,
#          -0.02251412,  0.04260239],
#         [ 0.01996524,  0.02389519, -0.04103314, -0.02647193,
#           0.04544778,  0.01303243,  0.00562643,  0.02604464,
#          -0.0294543 ,  0.00206136],
#         [ 0.04432554, -0.02949274,  0.00618243,  0.02000041,
#          -0.0274101 ,  0.00867223,  0.00422277, -0.01694552,
#          -0.03290661,  0.02646024],
#         [ 0.03460152,  0.03483727, -0.03128891, -0.01398767,
#          -0.03642939,  0.03353511, -0.04707205,  0.0089894 ,
#           0.00123965, -0.01814901]],
#
#        [[-0.02330211,  0.01627814, -0.04349464,  0.02309198,
#          -0.0032322 ,  0.01108183, -0.04514333, -0.00697652,
#          -0.00330598, -0.02367705],
#         [-0.02330211,  0.01627814, -0.04349464,  0.02309198,
#          -0.0032322 ,  0.01108183, -0.04514333, -0.00697652,
#          -0.00330598, -0.02367705],
#         [-0.02330211,  0.01627814, -0.04349464,  0.02309198,
#          -0.0032322 ,  0.01108183, -0.04514333, -0.00697652,
#          -0.00330598, -0.02367705],
#         [-0.02330211,  0.01627814, -0.04349464,  0.02309198,
#          -0.0032322 ,  0.01108183, -0.04514333, -0.00697652,
#          -0.00330598, -0.02367705],
#         [-0.02474662,  0.04817319, -0.03042429,  0.01218791,
#           0.04978902,  0.0418851 , -0.01984539,  0.04739294,
#           0.03985274,  0.02848247],
#         [-0.01350876, -0.00870768,  0.00800725,  0.04443313,
#          -0.01926832, -0.01500611, -0.0336972 , -0.01741806,
#           0.03572286,  0.03582181],
#         [ 0.00144026,  0.04361093, -0.03434487,  0.03267669,
#           0.00433538,  0.02870183,  0.03347463,  0.0067892 ,
#           0.02028244,  0.01090422],
#         [-0.04801533,  0.01840714,  0.04043165, -0.03367736,
#          -0.04605852, -0.04235249, -0.04783267,  0.03856683,
#          -0.02810522,  0.03464666]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 3547, 1904, 1027, 9550])
