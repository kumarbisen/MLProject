# %%
import tensorflow as tf
from tensorflow.keras import models,layers
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 32
CHANNELS = 3
EPOCHS=50

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "../PlantVillage",
    shuffle=True,
    image_size= IMAGE_SIZE,
    batch_size = BATCH_SIZE
)
# Out:
# Found 2152 files belonging to 3 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
len(dataset)
# Out:
# 68

# %%
plt.figure(figsize=(15,15))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        ax=plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[label_batch[i]])
        plt.axis("off")

# %%
# 80% ==> training
# 20% ==> 10%validation, 10% test

# %%
def get_dataset_partitions_tf(ds, train_split=0.8,val_split=0.1,test_split=0.1,shuffle=True, shuffle_size=30000):

        ds_size = len(ds)
        if shuffle:
                ds = ds.shuffle(shuffle_size* ds_size)

        train_size = int(train_split*ds_size)
        val_size = int(val_split*ds_size)

        train_ds = ds.take(train_size)
        val_ds = ds.skip(train_size).take(val_size)

        test_ds = ds.skip(train_size).skip(val_size)
        return train_ds ,val_ds, test_ds

# %%
get_dataset_partitions_tf(dataset)
# Out:
# (<_TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>,
#  <_TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>,
#  <_SkipDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>)

# %%
train_ds,val_ds,test_ds = get_dataset_partitions_tf(dataset)

# %%
a = len(train_ds)
b = len(val_ds)
c = len(test_ds)

print(a,b,c)
# Out:
# 54 6 8

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(IMAGE_SIZE,IMAGE_SIZE),
    layers.Rescaling(1.0/255)
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
])

# %%
input_shape = (BATCH_SIZE,IMAGE_SIZE,IMAGE_SIZE,CHANNELS)
n_classes = 15


model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(32,(3,3), activation='relu',input_shape=input_shape),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size=(3,3), activation="relu"),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size=(3,3), activation="relu"),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size=(3,3), activation="relu"),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size=(3,3), activation="relu"),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size=(3,3), activation="relu"),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(64,activation="relu"),
    layers.Dense(n_classes,activation='softmax')
    
])

model.build(input_shape=input_shape)
# Out:
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (32, 256, 256, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ (32, 256, 256, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (32, 254, 254, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (32, 127, 127, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (32, 125, 125, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (32, 62, 62, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (32, 60, 60, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (32, 30, 30, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (32, 28, 28, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (32, 14, 14, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (32, 12, 12, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (32, 6, 6, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (32, 4, 4, 64)         │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (32, 2, 2, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (32, 256)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (32, 64)               │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (32, 15)               │           975 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 184,527 (720.81 KB)
#  Trainable params: 184,527 (720.81 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(

    optimizer ="adam",
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics = ['accuracy']
)

# %%
# Retrain the model 
Train = model.fit(
    train_ds,
    epochs =EPOCHS,
    batch_size = BATCH_SIZE,
    verbose =1,
    validation_data = val_ds
)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7304\4009571666.py in ?()
# ----> 1 Train = model.fit(
#       2     train_ds,
#       3     epochs =EPOCHS,
#       4     batch_size = BATCH_SIZE,
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py in ?(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     373             callbacks.on_epoch_begin(epoch)
#     374             with epoch_iterator.catch_stop_iteration():
#     375                 for begin_step, end_step, iterator in epoch_iterator:
#     376                     callbacks.on_train_batch_begin(begin_step)
# --> 377                     logs = self.train_function(iterator)
#     378                     callbacks.on_train_batch_end(end_step, logs)
#     379                     if self.stop_training:
#     380                         break
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py in ?(iterator)
#     216         def function(iterator):
#     217             if isinstance(
#     218                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     219             ):
# --> 220                 opt_outputs = multi_step_on_iterator(iterator)
#     221                 if not opt_outputs.has_value():
#     222                     raise StopIteration
#     223                 return opt_outputs.get_value()
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in ?(self, *args, **kwds)
#     829       # TODO(cheshire): Do not duplicate the XLAControlFlowContext annotation.
#     830       compiler = "xla" if self._jit_compile else "nonXla"
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#     836       without_tracing = (tracing_count == new_tracing_count)
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in ?(self, *args, **kwds)
#     889       self._initialize(args, kwds, add_initializers_to=initializers)
#     890     finally:
#     891       # At this point we know that the initialization is complete (or less
#     892       # interestingly an exception was raised) so we no longer need a lock.
# --> 893       self._lock.release()
#     894
#     895     if self._created_variables:
#     896       try:
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in ?(self, args, kwds, add_initializers_to)
#     692         variable_capturing_scope,
#     693         tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694     )
#     695     # Force the definition of the function for these arguments
# --> 696     self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697         args, kwds, self._variable_creation_config
#     698     )
#     699
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py in ?(args, kwargs, tracing_options)
#     174     if tracing_options.input_signature and not args and not kwargs:
#     175       args = tracing_options.input_signature
#     176       kwargs = {}
#     177
# --> 178     concrete_function = _maybe_define_function(
#     179         args, kwargs, tracing_options
#     180     )
#     181
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py in ?(args, kwargs, tracing_options)
#     279               current_func_context, lookup_func_type
#     280           )
#     281         else:
#     282           target_func_type = lookup_func_type
# --> 283         concrete_function = _create_concrete_function(
#     284             target_func_type, lookup_func_context, func_graph, tracing_options
#     285         )
#     286
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py in ?(function_type, type_context, func_graph, tracing_options)
#     306
#     307   disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308       attributes_lib.DISABLE_ACD, False
#     309   )
# --> 310   traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311       tracing_options.name,
#     312       tracing_options.python_function,
#     313       placeholder_bound_args.args,
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\framework\func_graph.py in ?(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056         x = deps_ctx.mark_as_return(x)
#    1057       return x
#    1058
#    1059     _, original_func = tf_decorator.unwrap(python_func)
# -> 1060     func_outputs = python_func(*func_args, **func_kwargs)
#    1061
#    1062     # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1063     # TensorArrays and `None`s.
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in ?(*args, **kwds)
#     595       with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597         # the function a weak reference to itself to avoid a reference cycle.
#     598         with OptionalXlaContext(compile_with_xla):
# --> 599           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600         return out
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\autograph_util.py in ?(*args, **kwargs)
#      46               recursive=True,
#      47               optional_features=autograph_options,
#      48               user_requested=True,
#      49           ))
# ---> 50     except Exception as e:  # pylint:disable=broad-except
#      51       if hasattr(e, "ag_error_metadata"):
#      52         raise e.ag_error_metadata.to_exception(e)
#      53       else:
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\autograph\impl\api.py in ?(f, args, kwargs, caller_fn_scope, options)
#     335     return _call_unconverted(f, args, kwargs, options, False)
#     336
#     337   if is_autograph_artifact(f):
#     338     logging.log(2, 'Permanently allowed: %s: AutoGraph artifact', f)
# --> 339     return _call_unconverted(f, args, kwargs, options)
#     340
#     341   # If this is a partial, unwrap it and redo all the checks.
#     342   if isinstance(f, functools.partial):
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\autograph\impl\api.py in ?(f, args, kwargs, options, update_cache)
#     455       isinstance(f.__self__, tf_method_target.TfMethodTarget)):
#     456     return f.__self__.call(args, kwargs)
#     457
#     458   if kwargs is not None:
# --> 459     return f(*args, **kwargs)
#     460   return f(*args)
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\autograph\impl\api.py in ?(*args, **kwargs)
#     641   def wrapper(*args, **kwargs):
#     642     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643       return func(*args, **kwargs)
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py in ?(iterator)
#     129         @tf.autograph.experimental.do_not_convert
#     130         def multi_step_on_iterator(iterator):
#     131             if self.steps_per_execution == 1:
#     132                 return tf.experimental.Optional.from_value(
# --> 133                     one_step_on_data(iterator.get_next())
#     134                 )
#     135
#     136             # the spec is set lazily during the tracing of `tf.while_loop`
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in ?(self, *args, **kwds)
#     829       # TODO(cheshire): Do not duplicate the XLAControlFlowContext annotation.
#     830       compiler = "xla" if self._jit_compile else "nonXla"
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#     836       without_tracing = (tracing_count == new_tracing_count)
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in ?(self, *args, **kwds)
#     889       self._initialize(args, kwds, add_initializers_to=initializers)
#     890     finally:
#     891       # At this point we know that the initialization is complete (or less
#     892       # interestingly an exception was raised) so we no longer need a lock.
# --> 893       self._lock.release()
#     894
#     895     if self._created_variables:
#     896       try:
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in ?(self, args, kwds, add_initializers_to)
#     692         variable_capturing_scope,
#     693         tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694     )
#     695     # Force the definition of the function for these arguments
# --> 696     self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697         args, kwds, self._variable_creation_config
#     698     )
#     699
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py in ?(args, kwargs, tracing_options)
#     174     if tracing_options.input_signature and not args and not kwargs:
#     175       args = tracing_options.input_signature
#     176       kwargs = {}
#     177
# --> 178     concrete_function = _maybe_define_function(
#     179         args, kwargs, tracing_options
#     180     )
#     181
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py in ?(args, kwargs, tracing_options)
#     279               current_func_context, lookup_func_type
#     280           )
#     281         else:
#     282           target_func_type = lookup_func_type
# --> 283         concrete_function = _create_concrete_function(
#     284             target_func_type, lookup_func_context, func_graph, tracing_options
#     285         )
#     286
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py in ?(function_type, type_context, func_graph, tracing_options)
#     306
#     307   disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308       attributes_lib.DISABLE_ACD, False
#     309   )
# --> 310   traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311       tracing_options.name,
#     312       tracing_options.python_function,
#     313       placeholder_bound_args.args,
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\framework\func_graph.py in ?(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056         x = deps_ctx.mark_as_return(x)
#    1057       return x
#    1058
#    1059     _, original_func = tf_decorator.unwrap(python_func)
# -> 1060     func_outputs = python_func(*func_args, **func_kwargs)
#    1061
#    1062     # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1063     # TensorArrays and `None`s.
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in ?(*args, **kwds)
#     595       with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597         # the function a weak reference to itself to avoid a reference cycle.
#     598         with OptionalXlaContext(compile_with_xla):
# --> 599           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600         return out
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\autograph_util.py in ?(*args, **kwargs)
#      46               recursive=True,
#      47               optional_features=autograph_options,
#      48               user_requested=True,
#      49           ))
# ---> 50     except Exception as e:  # pylint:disable=broad-except
#      51       if hasattr(e, "ag_error_metadata"):
#      52         raise e.ag_error_metadata.to_exception(e)
#      53       else:
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\autograph\impl\api.py in ?(f, args, kwargs, caller_fn_scope, options)
#     335     return _call_unconverted(f, args, kwargs, options, False)
#     336
#     337   if is_autograph_artifact(f):
#     338     logging.log(2, 'Permanently allowed: %s: AutoGraph artifact', f)
# --> 339     return _call_unconverted(f, args, kwargs, options)
#     340
#     341   # If this is a partial, unwrap it and redo all the checks.
#     342   if isinstance(f, functools.partial):
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\autograph\impl\api.py in ?(f, args, kwargs, options, update_cache)
#     455       isinstance(f.__self__, tf_method_target.TfMethodTarget)):
#     456     return f.__self__.call(args, kwargs)
#     457
#     458   if kwargs is not None:
# --> 459     return f(*args, **kwargs)
#     460   return f(*args)
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\autograph\impl\api.py in ?(*args, **kwargs)
#     641   def wrapper(*args, **kwargs):
#     642     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643       return func(*args, **kwargs)
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py in ?(data)
#     111         @tf.autograph.experimental.do_not_convert
#     112         def one_step_on_data(data):
#     113             """Runs a single training step on a batch of data."""
# --> 114             outputs = self.distribute_strategy.run(step_function, args=(data,))
#     115             outputs = reduce_per_replica(
#     116                 outputs,
#     117                 self.distribute_strategy,
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py in ?(***failed resolving arguments***)
#    1669       # tf.distribute supports Eager functions, so AutoGraph should not be
#    1670       # applied when the caller is also in Eager mode.
#    1671       fn = autograph.tf_convert(
#    1672           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1673       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py in ?(self, fn, args, kwargs)
#    3259     _require_cross_replica_or_default_context_extended(self)
#    3260     if kwargs is None:
#    3261       kwargs = {}
#    3262     with self._container_strategy().scope():
# -> 3263       return self._call_for_each_replica(fn, args, kwargs)
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py in ?(self, fn, args, kwargs)
#    4059   def _call_for_each_replica(self, fn, args, kwargs):
#    4060     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4061       return fn(*args, **kwargs)
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\autograph\impl\api.py in ?(*args, **kwargs)
#     641   def wrapper(*args, **kwargs):
#     642     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643       return func(*args, **kwargs)
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py in ?(self, data)
#      54
#      55         # Forward pass
#      56         with tf.GradientTape() as tape:
#      57             if self._call_has_training_arg:
# ---> 58                 y_pred = self(x, training=True)
#      59             else:
#      60                 y_pred = self(x)
#      61             loss = self._compute_loss(
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\layers\layer.py in ?(self, *args, **kwargs)
#     975                     "layers will not see the mask."
#     976                 )
#     977         finally:
#     978             # Destroy call context if we created it
# --> 979             self._maybe_reset_call_context()
#     980
#     981         ################################################
#     982         # 8. Add a node in the graph for symbolic calls.
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\ops\operation.py in ?(self, *args, **kwargs)
#      55             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56                 call_fn,
#      57                 object_name=(f"{self.__class__.__name__}.call()"),
#      58             )
# ---> 59             return call_fn(*args, **kwargs)
#      60
#      61         # Plain flow.
#      62         if any_symbolic_tensors(args, kwargs):
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\models\sequential.py in ?(self, inputs, training, mask, **kwargs)
#     218     def call(self, inputs, training=None, mask=None, **kwargs):
#     219         if self._functional:
# --> 220             return self._functional.call(
#     221                 inputs, training=training, mask=mask, **kwargs
#     222             )
#     223
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\models\functional.py in ?(self, inputs, training, mask, **kwargs)
#     179             masks = tree.flatten(mask)
#     180             for x, mask in zip(inputs, masks):
#     181                 if mask is not None:
#     182                     backend.set_keras_mask(x, mask)
# --> 183         outputs = self._run_through_graph(
#     184             inputs,
#     185             operation_fn=lambda op: operation_fn(
#     186                 op, training=training, **kwargs
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\ops\function.py in ?(self, inputs, operation_fn, call_fn)
#     202                 else:
#     203                     # Use NNX operation mapping
#     204                     operation = self._get_operation_for_node(node)
#     205                     op = operation_fn(operation)
# --> 206                     outputs = op(*args, **kwargs)
#     207
#     208                 # Update tensor_dict.
#     209                 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\models\functional.py in ?(*args, **kwargs)
#     640                 and value is not None
#     641             ):
#     642                 kwargs[name] = value
#     643
# --> 644         return operation(*args, **kwargs)
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\layers\layer.py in ?(self, *args, **kwargs)
#     975                     "layers will not see the mask."
#     976                 )
#     977         finally:
#     978             # Destroy call context if we created it
# --> 979             self._maybe_reset_call_context()
#     980
#     981         ################################################
#     982         # 8. Add a node in the graph for symbolic calls.
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\ops\operation.py in ?(self, *args, **kwargs)
#      55             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56                 call_fn,
#      57                 object_name=(f"{self.__class__.__name__}.call()"),
#      58             )
# ---> 59             return call_fn(*args, **kwargs)
#      60
#      61         # Plain flow.
#      62         if any_symbolic_tensors(args, kwargs):
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\models\sequential.py in ?(self, inputs, training, mask, **kwargs)
#     218     def call(self, inputs, training=None, mask=None, **kwargs):
#     219         if self._functional:
# --> 220             return self._functional.call(
#     221                 inputs, training=training, mask=mask, **kwargs
#     222             )
#     223
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\models\functional.py in ?(self, inputs, training, mask, **kwargs)
#     179             masks = tree.flatten(mask)
#     180             for x, mask in zip(inputs, masks):
#     181                 if mask is not None:
#     182                     backend.set_keras_mask(x, mask)
# --> 183         outputs = self._run_through_graph(
#     184             inputs,
#     185             operation_fn=lambda op: operation_fn(
#     186                 op, training=training, **kwargs
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\ops\function.py in ?(self, inputs, operation_fn, call_fn)
#     202                 else:
#     203                     # Use NNX operation mapping
#     204                     operation = self._get_operation_for_node(node)
#     205                     op = operation_fn(operation)
# --> 206                     outputs = op(*args, **kwargs)
#     207
#     208                 # Update tensor_dict.
#     209                 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\models\functional.py in ?(*args, **kwargs)
#     640                 and value is not None
#     641             ):
#     642                 kwargs[name] = value
#     643
# --> 644         return operation(*args, **kwargs)
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py in ?(self, inputs, **kwargs)
#      43                 outputs = super().__call__(inputs, **kwargs)
#      44             finally:
#      45                 self.backend.reset()
#      46                 if switch_convert_input_args:
# ---> 47                     self._convert_input_args = True
#      48             return outputs
#      49         return super().__call__(inputs, **kwargs)
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\layers\layer.py in ?(self, *args, **kwargs)
#     975                     "layers will not see the mask."
#     976                 )
#     977         finally:
#     978             # Destroy call context if we created it
# --> 979             self._maybe_reset_call_context()
#     980
#     981         ################################################
#     982         # 8. Add a node in the graph for symbolic calls.
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\ops\operation.py in ?(self, *args, **kwargs)
#      55             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56                 call_fn,
#      57                 object_name=(f"{self.__class__.__name__}.call()"),
#      58             )
# ---> 59             return call_fn(*args, **kwargs)
#      60
#      61         # Plain flow.
#      62         if any_symbolic_tensors(args, kwargs):
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\layers\preprocessing\image_preprocessing\base_image_preprocessing_layer.py in ?(self, data, training)
#     131     def call(self, data, training=True):
# --> 132         transformation = self.get_random_transformation(data, training=training)
#     133         if isinstance(data, dict):
#     134             is_batched = self._is_batched(data["images"])
#     135             if is_batched:
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\layers\preprocessing\image_preprocessing\random_flip.py in ?(self, data, training, seed)
#      81         if seed is None:
#      82             seed = self._get_seed_generator(self.backend._backend)
#      83
#      84         flips = self.backend.numpy.less_equal(
# ---> 85             self.backend.random.uniform(shape=flips_shape, seed=seed), 0.5
#      86         )
#      87         return {"flips": flips, "input_shape": shape}
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\keras\src\backend\tensorflow\random.py in ?(shape, minval, maxval, dtype, seed)
#      31 def uniform(shape, minval=0.0, maxval=1.0, dtype=None, seed=None):
#      32     dtype = dtype or floatx()
#      33     seed = _cast_seed(draw_seed(seed))
# ---> 34     return tf.random.stateless_uniform(
#      35         shape=shape,
#      36         minval=tf.cast(minval, dtype),
#      37         maxval=tf.cast(maxval, dtype),
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1261
#    1262       # Fallback dispatch system (dispatch v1):
#    1263       try:
#    1264         return dispatch_target(*args, **kwargs)
# -> 1265       except (TypeError, ValueError):
#    1266         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1267         # TypeError, when given unexpected types.  So we need to catch both.
#    1268         result = dispatch(op_dispatch_handler, args, kwargs)
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\ops\stateless_random_ops.py in ?(shape, seed, minval, maxval, dtype, name, alg)
#     377     maxval = 1
#     378   with ops.name_scope(
#     379       name, "stateless_random_uniform", [shape, seed, minval, maxval]
#     380   ) as name:
# --> 381     shape = shape_util.shape_tensor(shape)
#     382     if dtype.is_integer and minval is None:
#     383       key, counter, alg = random_ops_util.get_key_counter_alg(seed, alg)
#     384       result = gen_stateless_random_ops_v2.stateless_random_uniform_full_int_v2(
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\ops\shape_util.py in ?(shape)
#      31       # problem if v1 and v2 TensorShape objects get mixed up in partial
#      32       # conversions, leading to shapes such as (1, 2, Dimension(5)), which are
#      33       # not convertible to Tensors because of mixed content.
#      34       shape = tuple(map(tensor_shape.dimension_value, shape))
# ---> 35   return ops.convert_to_tensor(shape, dtype=dtype, name="shape")
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\profiler\trace.py in ?(*args, **kwargs)
#     179     def wrapped(*args, **kwargs):
#     180       if enabled:
#     181         with Trace(trace_name, **trace_kwargs):
#     182           return func(*args, **kwargs)
# --> 183       return func(*args, **kwargs)
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\framework\ops.py in ?(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     753 ) -> Union[EagerTensor, SymbolicTensor]:
#     754   """Implementation of the public convert_to_tensor."""
#     755   # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     756   preferred_dtype = preferred_dtype or dtype_hint
# --> 757   return tensor_conversion_registry.convert(
#     758       value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     759   )
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py in ?(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     230                   f"actual = {ret.dtype.base_dtype.name}",
#     231                   name=name))
#     232
#     233     if ret is None:
# --> 234       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     235
#     236     if ret is NotImplemented:
#     237       continue
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\ops\array_ops.py in ?(v, dtype, name, as_ref)
#    1334   if dtype is None:
#    1335     dtype = inferred_dtype
#    1336   elif dtype != inferred_dtype:
#    1337     v = nest.map_structure(_cast_nested_seqs_to_dtype(dtype), v)
# -> 1338   return _autopacking_helper(v, dtype, name or "packed")
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\ops\array_ops.py in ?(list_or_tuple, dtype, name)
#    1238           # handle the case where the list arguments are other
#    1239           # convertible-to-tensor types, such as numpy arrays.
#    1240           elems_as_tensors.append(
#    1241               constant_op.constant(elem, dtype=dtype, name=str(i)))
# -> 1242       return gen_array_ops.pack(elems_as_tensors, name=scope)
#    1243     else:
#    1244       return converted_elems
#
# c:\MLProject\CNN\cnnvenv\Lib\site-packages\tensorflow\python\ops\gen_array_ops.py in ?(values, axis, name)
#    6765           values, axis=axis, name=name, ctx=_ctx)
#    6766     except _core._SymbolicException:
#    6767       pass  # Add nodes to the TensorFlow graph.
#    6768   # Add nodes to the TensorFlow graph.
# -> 6769   if not isinstance(values, (list, tuple)):
#    6770     raise TypeError(
#    6771         "Expected list for 'values' argument to "
#    6772         "'pack' Op, not %r." % values)
#
# KeyboardInterrupt:

# %%
import numpy as np 
for images_batch,labels_batch in test_ds.take(1):
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("image to predict")
    plt.imshow(first_image)

    print("Actual label:" ,class_names[first_label])
    batch_prediction = model.predict(images_batch)
    print("Predicted image:",class_names[np.argmax(batch_prediction[0])])

    confidence_score = round(100 * np.max(batch_prediction[0]), 2)
    print("Confidence Score: ", confidence_score,"%")
# Out:
# image to predict
# Actual label: Potato___Late_blight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# Predicted image: Potato___healthy
# Confidence Score:  7.11 %

# %%
import os
model_version = 1
save_dir = f'../PlantDiseaseModel{model_version}'
os.makedirs(save_dir, exist_ok=True)

model_path = os.path.join(save_dir, 'model.h5')

# %%
model.save(model_path)
print(f"Model saved at {model_path}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved at ../PlantDiseaseModel1\model.h5

# %%
model_version=1
model.save("planyDisease.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
